# %%
import pandas as pd

# %%
import os

# %%
from os import listdir

def find_csv_filenames( path_to_dir, suffix=".csv" ):
    filenames = listdir(path_to_dir)
    return [filename for filename in filenames if filename.endswith( suffix )]

# %%
file_names = find_csv_filenames('./')

# %%
file_names
# Out:
# ['game_2023-2024.csv']

# %%
df_23 = pd.read_csv("game_2023-2024.csv")

# %%
df_23.head()
# Out:
#    Rk Team        Date  PTS Unnamed: 4  Opp          Result   MP  FG  FGA  \
# 0   1  IND  2023-11-21  157          @  ATL       W 157-152  240  57   94
# 1   2  BOS  2023-11-01  155        NaN  IND       W 155-104  240  54   95
# 2   3  UTA  2024-01-03  154        NaN  DET  W 154-148 (OT)  265  53  103
# 3   4  NOP  2024-01-23  153        NaN  UTA       W 153-124  240  60  104
# 4   5  ATL  2023-11-21  152        NaN  IND       L 152-157  240  57   95
#
#    ...  2P.1  2PA.1  2P%.1  3P.1  3PA.1  3P%.1  FT.1  FTA.1  FT%.1  PTS.2
# 0  ...    42     64  0.656    15     31  0.484    23     28  0.821    152
# 1  ...    41     64  0.641     5     37  0.135     7     12  0.583    104
# 2  ...    37     64  0.578    19     41  0.463    17     22  0.773    148
# 3  ...    31     56  0.554    12     36  0.333    26     32  0.813    124
# 4  ...    35     49  0.714    22     45  0.489    21     28  0.750    157
#
# [5 rows x 34 columns]

# %%
lis = list(df_23.columns)

# %%
pop_fields = lis

# %%
df_23.iloc[0]
# Out:
# Rk                     1
# Team                 IND
# Date          2023-11-21
# PTS                  157
# Unnamed: 4             @
# Opp                  ATL
# Result         W 157-152
# MP                   240
# FG                    57
# FGA                   94
# FG%                0.606
# 2P                    35
# 2PA                   49
# 2P%                0.714
# 3P                    22
# 3PA                   45
# 3P%                0.489
# FT                    21
# FTA                   28
# FT%                 0.75
# PTS.1                157
# FG.1                  57
# FGA.1                 95
# FG%.1                0.6
# 2P.1                  42
# 2PA.1                 64
# 2P%.1              0.656
# 3P.1                  15
# 3PA.1                 31
# 3P%.1              0.484
# FT.1                  23
# FTA.1                 28
# FT%.1              0.821
# PTS.2                152
# Name: 0, dtype: object

# %%
res = list(df_23.iloc[0])

# %%
pop_indexes = [0, 1, 2, 3, 4, 5]

pop_fields.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pop_fields.pop([1, 2, 3])
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
df_23.iloc[0]['Result']
# Out:
# 'W 157-152'

# %%
for i in range(len(df_23)):
    df_23.iloc[i]['Rk'] = 10110010101
    break
# Out:
# C:\Users\YGP\AppData\Local\Temp\ipykernel_15564\2286629081.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_23.iloc[i]['Rk'] = 10110010101

# %%
df_23.iloc[0]['Rk']
# Out:
# 1

# %%
df_23['Rk'][0] = 1293219
# Out:
# C:\Users\YGP\AppData\Local\Temp\ipykernel_15564\3258703094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_23['Rk'][0] = 1293219

# %%
df_23['Result'][0] = 1
# Out:
# C:\Users\YGP\AppData\Local\Temp\ipykernel_15564\80975662.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_23['Result'][0] = 1

# %%
for index in range(len(df_23)):
    if df_23['Result'][index][0] == 'W':
        df_23['Result'][index] = 1
    else:
        df_23['Result'][index] = 0
# Out:
# C:\Users\YGP\AppData\Local\Temp\ipykernel_15564\2091137164.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_23['Result'][index] = 1
# C:\Users\YGP\AppData\Local\Temp\ipykernel_15564\2091137164.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_23['Result'][index] = 1
# C:\Users\YGP\AppData\Local\Temp\ipykernel_15564\2091137164.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_23['Result'][index] = 1
# ...

# %%
df_23.head()
# Out:
#    Rk Team        Date  PTS Unnamed: 4  Opp Result   MP  FG  FGA  ...  2P.1  \
# 0   1  IND  2023-11-21  157          @  ATL      1  240  57   94  ...    42
# 1   2  BOS  2023-11-01  155        NaN  IND      1  240  54   95  ...    41
# 2   3  UTA  2024-01-03  154        NaN  DET      1  265  53  103  ...    37
# 3   4  NOP  2024-01-23  153        NaN  UTA      1  240  60  104  ...    31
# 4   5  ATL  2023-11-21  152        NaN  IND      0  240  57   95  ...    35
#
#    2PA.1  2P%.1  3P.1  3PA.1  3P%.1  FT.1  FTA.1  FT%.1  PTS.2
# 0     64  0.656    15     31  0.484    23     28  0.821    152
# 1     64  0.641     5     37  0.135     7     12  0.583    104
# 2     64  0.578    19     41  0.463    17     22  0.773    148
# 3     56  0.554    12     36  0.333    26     32  0.813    124
# 4     49  0.714    22     45  0.489    21     28  0.750    157
#
# [5 rows x 34 columns]

# %%
df_23.to_csv("")
